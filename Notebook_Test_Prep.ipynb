# %%
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import tensorflow as tf 
import os
import cv2
import hpacellseg.cellsegmentator as cellsegmentator
from hpacellseg.utils import label_cell
from PIL import Image
from typing import Tuple, List
import warnings
from torch.serialization import SourceChangeWarning
warnings.filterwarnings("ignore", category=SourceChangeWarning)


NUC_MODEL = '/media/beta/mitko-beps/segmentator/model_paths/dpn_unet_nuclei_v1.pth' #./nuclei_model.pth
CELL_MODEL = '/media/beta/mitko-beps/segmentator/model_paths/dpn_unet_cell_3ch_v1.pth'

def build_image_names(image_id: str) -> Tuple[List[str], List[str], List[str], List[str], List[List[str]]]:
    # red = microtubule
    mt = f'/media/beta/mitko-beps/data/test/{image_id}_red.png'

    # blue = nuclei
    nu = f'/media/beta/mitko-beps/data/test/{image_id}_blue.png'

    # yellow = endoplasmic reticulum
    er = f'/media/beta/mitko-beps/data/test/{image_id}_yellow.png'

    # green = target protein
    tp = f'/media/beta/mitko-beps/data/test/{image_id}_green.png'

    return [mt], [er], [nu], [tp], [[mt], [er], [nu]]


segmentator = cellsegmentator.CellSegmentator(
    NUC_MODEL,
    CELL_MODEL,
    scale_factor=0.25,
    device='cpu',
    padding=False,
    multi_channel_model=True)

def pad(img, h, w):
    #  in case when you have odd number
    # Function to padd the images
    top_pad = np.floor((h - img.shape[0]) / 2).astype(np.uint16)
    bottom_pad = np.ceil((h - img.shape[0]) / 2).astype(np.uint16)
    right_pad = np.ceil((w - img.shape[1]) / 2).astype(np.uint16)
    left_pad = np.floor((w - img.shape[1]) / 2).astype(np.uint16)
    return np.copy(np.pad(img, ((top_pad, bottom_pad), (left_pad, right_pad), (0, 0)), mode='constant', constant_values=0))


def segment_picture(image_name):
    names = build_image_names(image_name)

    cell_segmentations = segmentator.pred_cells(names[-1])
    nuc_segmentations = segmentator.pred_nuclei(names[2])

    _, cell_mask = label_cell(nuc_segmentations[0], cell_segmentations[0])
    
    mt = plt.imread(names[0][0])  #names[0][0] = string, names[0] = list
    er = plt.imread(names[1][0])
    nu = plt.imread(names[2][0])
    tp = plt.imread(names[3][0])
    
    cell_masks = []
    
    #For each mask
    for cell in set(cell_mask.flatten()):  #set zet in volgorde
        if cell == 0:
            continue
        mask_individual_cell = cell_mask == cell

        cell_masks.append(mask_individual_cell)
        
        a = np.where(cell_mask == cell)
        first_y, last_y, first_x, last_x = np.min(a[0]), np.max(a[0]), np.min(a[1]), np.max(a[1])

        sub_img = mask_individual_cell[first_y: last_y, first_x: last_x]

        final_img_mt = np.where(mask_individual_cell[first_y: last_y, first_x: last_x] == False, np.zeros_like(sub_img),
 mt[first_y: last_y, first_x: last_x])
        final_img_er = np.where(mask_individual_cell[first_y: last_y, first_x: last_x] == False, np.zeros_like(sub_img),
 er[first_y: last_y, first_x: last_x])
        final_img_nu = np.where(mask_individual_cell[first_y: last_y, first_x: last_x] == False, np.zeros_like(sub_img),
 nu[first_y: last_y, first_x: last_x])
        final_img_tp = np.where(mask_individual_cell[first_y: last_y, first_x: last_x] == False, np.zeros_like(sub_img),
 tp[first_y: last_y, first_x: last_x])
        a = np.where(cell_mask == cell)
        
        img = np.dstack((final_img_mt, final_img_nu, final_img_er, final_img_tp))
        
        
        target_size = (224, 224)
        size = (img.shape[0], img.shape[1])
        batch_shape = (224, 224, 4)
        batch_center = np.array(batch_shape[:2])//2

        if size[0] <= target_size[0] and size[1] <= target_size[1]:
            new_img = pad(img, target_size[0], target_size[1])

        else:
            axis_to_add = size[0] > size[1]
            pixels_to_add = max(size) - min(size)

            if axis_to_add:
                new_block = np.zeros((size[int(not axis_to_add)], pixels_to_add // 2, 4))
                new_block_2 = np.zeros((size[int(not axis_to_add)], int(pixels_to_add % 2 != 0) + pixels_to_add // 2, 4)
)
            else:
                new_block = np.zeros((pixels_to_add // 2, size[int(not axis_to_add)], 4))
                new_block_2 = np.zeros((int(pixels_to_add % 2 != 0) + pixels_to_add // 2, size[int(not axis_to_add)], 4)
)
            new_img = np.concatenate((new_block, img, new_block_2), axis=int(axis_to_add))
            assert new_img.shape[0] == new_img.shape[1]
            new_img = tf.image.resize(new_img, batch_shape[:2])

        image_arr = np.array(new_img)
        root = "/media/beta/mitko-beps/heather/TestSeg/" + image_name + "_" + str(cell) + ".npy"
        np.save(root, image_arr)
    
    return max(set(cell_mask.flatten())), cell_masks

# %%
import base64
import numpy as np
import os 
import pandas as pd
from pycocotools import _mask as coco_mask
import typing as t
import zlib


def encode_binary_mask(mask: np.ndarray) -> t.Text:
    """Converts a binary mask into OID challenge encoding ascii text."""

    # check input mask --
    if mask.dtype != np.bool:
        raise ValueError(
           "encode_binary_mask expects a binary mask, received dtype == %s" %
           mask.dtype)

    mask = np.squeeze(mask)
    if len(mask.shape) != 2:
        raise ValueError(
           "encode_binary_mask expects a 2d mask, received shape == %s" %
           mask.shape)

     # convert input mask to expected COCO API input --
    mask_to_encode = mask.reshape(mask.shape[0], mask.shape[1], 1)
    mask_to_encode = mask_to_encode.astype(np.uint8)
    mask_to_encode = np.asfortranarray(mask_to_encode)

    # RLE encode mask --
    encoded_mask = coco_mask.encode(mask_to_encode)[0]["counts"]

    # compress and base64 encoding --
    binary_str = zlib.compress(encoded_mask, zlib.Z_BEST_COMPRESSION)
    base64_str = base64.b64encode(binary_str)
    return base64_str.decode("utf-8")

# %%
test_df = pd.read_csv("/media/beta/mitko-beps/data/sample_submission.csv")
test_df["n_cells"] = 0
test_df["Encoded_Masks"] = ""

c = len(test_df)
all_enc_masks = []
for n, i in enumerate(test_df['ID']):
    start_time = time.time()
    try: 
        i = i.split('/')[-1]
        cells, cell_masks = segment_picture(i)
        test_df.loc[test_df['ID'] == i, 'n_cells'] = cells
    except:
        print('error in ' + i)
        with open('/media/beta/mitko-beps/heather/errors_1.txt', 'a') as f:
            f.write(i + '\n')
        cells = -1
    
    encoded_masks = []
                
    for mask in cell_masks: 
        encoded_mask = encode_binary_mask(mask)
        encoded_masks.append(encoded_mask)
    
    all_enc_masks.append(encoded_masks)
    #test_df.iat[n, test_df.columns.get_loc('Encoded_Masks')] = encoded_masks
    #test_df.loc[test_df["ID"] == i, "Encoded_Masks"] == encoded_masks
    
    print("{} out of {}, {:.2f}%.  {} cells segmented".format(n + 1, c, 100 * n / c, cells))
    print("took {:.2f}s".format(time.time()-start_time))
    print()
    
        

test_df.to_csv('/media/beta/mitko-beps/heather/test_with_masks_1.csv')
np.save("/media/beta/mitko-beps/heather/encoded_masks_1.npy", all_enc_masks)
# Out:
# 1 out of 559, 0.00%.  15 cells segmented
# took 23.06s
#
# 2 out of 559, 0.18%.  12 cells segmented
# took 21.60s
#
# 3 out of 559, 0.36%.  36 cells segmented
# took 25.24s
#
# 4 out of 559, 0.54%.  22 cells segmented
# took 21.73s
#
# 5 out of 559, 0.72%.  34 cells segmented
# took 54.42s
#
# 6 out of 559, 0.89%.  21 cells segmented
# took 22.12s
#
# error in 020a29cf-2c24-478b-8603-c22a90dc3e31
# 7 out of 559, 1.07%.  -1 cells segmented
# took 3.34s
#
# 8 out of 559, 1.25%.  16 cells segmented
# took 23.25s
#
# 9 out of 559, 1.43%.  32 cells segmented
# took 26.29s
#
# 10 out of 559, 1.61%.  22 cells segmented
# took 21.85s
#
# 11 out of 559, 1.79%.  12 cells segmented
# took 22.84s
#
# error in 02b3c5aa-d70c-49d1-b3e5-3f5cc10375ca
# 12 out of 559, 1.97%.  -1 cells segmented
# took 3.17s
#
# error in 02f9ee97-bf2e-4d9d-bdfd-b903ec2e79c0
# 13 out of 559, 2.15%.  -1 cells segmented
# took 2.98s
#
# 14 out of 559, 2.33%.  30 cells segmented
# took 23.95s
#
# 15 out of 559, 2.50%.  20 cells segmented
# took 22.83s
#
# 16 out of 559, 2.68%.  16 cells segmented
# took 21.51s
#
# 17 out of 559, 2.86%.  21 cells segmented
# took 22.80s
#
# 18 out of 559, 3.04%.  45 cells segmented
# took 26.68s
#
# 19 out of 559, 3.22%.  10 cells segmented
# took 20.39s
#
# 20 out of 559, 3.40%.  13 cells segmented
# took 22.67s
#
# 21 out of 559, 3.58%.  8 cells segmented
# took 21.67s
#
# 22 out of 559, 3.76%.  10 cells segmented
# took 22.51s
#
# 23 out of 559, 3.94%.  10 cells segmented
# took 22.03s
#
# 24 out of 559, 4.11%.  14 cells segmented
# took 22.67s
#
# 25 out of 559, 4.29%.  17 cells segmented
# took 23.90s
#
# 26 out of 559, 4.47%.  16 cells segmented
# took 23.10s
#
# 27 out of 559, 4.65%.  21 cells segmented
# took 24.35s
#
# error in 0c57f7f4-c9b9-4824-aa0e-c98bd8860434
# 28 out of 559, 4.83%.  -1 cells segmented
# took 3.68s
#
# 29 out of 559, 5.01%.  15 cells segmented
# took 22.50s
#
# 30 out of 559, 5.19%.  25 cells segmented
# took 23.08s
#
# 31 out of 559, 5.37%.  21 cells segmented
# took 22.96s
#
# 32 out of 559, 5.55%.  9 cells segmented
# took 20.62s
#
# 33 out of 559, 5.72%.  26 cells segmented
# took 22.92s
#
# error in 0e498bec-8155-4f31-9a23-8ebc5efe9dd7
# 34 out of 559, 5.90%.  -1 cells segmented
# took 3.44s
#
# 35 out of 559, 6.08%.  18 cells segmented
# took 22.83s
#
# 36 out of 559, 6.26%.  24 cells segmented
# took 26.48s
#
# error in 0ec42e43-bb66-41a0-bd95-d143d10ca78a
# 37 out of 559, 6.44%.  -1 cells segmented
# took 3.45s
#
# 38 out of 559, 6.62%.  10 cells segmented
# took 20.59s
#
# error in 0f0b6d5d-642d-4d63-97ee-dcf4b2a9203e
# 39 out of 559, 6.80%.  -1 cells segmented
# took 2.95s
#
# 40 out of 559, 6.98%.  23 cells segmented
# took 24.09s
#
# 41 out of 559, 7.16%.  17 cells segmented
# took 20.87s
#
# 42 out of 559, 7.33%.  16 cells segmented
# took 22.73s
#
# 43 out of 559, 7.51%.  14 cells segmented
# took 23.26s
#
# 44 out of 559, 7.69%.  17 cells segmented
# took 20.86s
#
# 45 out of 559, 7.87%.  11 cells segmented
# took 22.56s
#
# 46 out of 559, 8.05%.  12 cells segmented
# took 22.05s
#
# 47 out of 559, 8.23%.  47 cells segmented
# took 27.95s
#
# 48 out of 559, 8.41%.  45 cells segmented
# took 27.13s
#
# 49 out of 559, 8.59%.  6 cells segmented
# took 19.23s
#
# 50 out of 559, 8.77%.  11 cells segmented
# took 22.79s
#
# 51 out of 559, 8.94%.  13 cells segmented
# took 22.49s
#
# 52 out of 559, 9.12%.  15 cells segmented
# took 24.64s
#
# 53 out of 559, 9.30%.  15 cells segmented
# took 21.70s
#
# 54 out of 559, 9.48%.  20 cells segmented
# took 22.69s
#
# 55 out of 559, 9.66%.  4 cells segmented
# took 18.67s
#
# 56 out of 559, 9.84%.  12 cells segmented
# took 22.67s
#
# error in 182bc913-abca-46a9-b5fa-416ea862d655
# 57 out of 559, 10.02%.  -1 cells segmented
# took 3.84s
#
# 58 out of 559, 10.20%.  24 cells segmented
# took 28.36s
#
# 59 out of 559, 10.38%.  12 cells segmented
# took 23.33s
#
# 60 out of 559, 10.55%.  14 cells segmented
# took 25.68s
#
# 61 out of 559, 10.73%.  25 cells segmented
# took 22.05s
#
# 62 out of 559, 10.91%.  12 cells segmented
# took 22.15s
#
# 63 out of 559, 11.09%.  22 cells segmented
# took 23.93s
#
# 64 out of 559, 11.27%.  18 cells segmented
# took 26.42s
#
# 65 out of 559, 11.45%.  23 cells segmented
# took 27.54s
#
# 66 out of 559, 11.63%.  22 cells segmented
# took 22.04s
#
# error in 1de83a24-4043-4367-9cfc-735e5d5f40fd
# 67 out of 559, 11.81%.  -1 cells segmented
# took 4.07s
#
# 68 out of 559, 11.99%.  13 cells segmented
# took 22.29s
#
# 69 out of 559, 12.16%.  15 cells segmented
# took 22.81s
#
# 70 out of 559, 12.34%.  29 cells segmented
# took 51.88s
#
# 71 out of 559, 12.52%.  21 cells segmented
# took 25.93s
#
# 72 out of 559, 12.70%.  26 cells segmented
# took 25.63s
#
# 73 out of 559, 12.88%.  23 cells segmented
# took 23.61s
#
# 74 out of 559, 13.06%.  10 cells segmented
# took 23.53s
#
# 75 out of 559, 13.24%.  25 cells segmented
# took 24.61s
#
# error in 22fa496b-f407-4df0-96ed-8942df0bcd9d
# 76 out of 559, 13.42%.  -1 cells segmented
# took 5.10s
#
# 77 out of 559, 13.60%.  5 cells segmented
# took 19.69s
#
# 78 out of 559, 13.77%.  11 cells segmented
# took 24.43s
#
# 79 out of 559, 13.95%.  21 cells segmented
# took 22.95s
#
# 80 out of 559, 14.13%.  21 cells segmented
# took 24.83s
#
# 81 out of 559, 14.31%.  27 cells segmented
# took 22.94s
#
# 82 out of 559, 14.49%.  12 cells segmented
# took 21.40s
#
# 83 out of 559, 14.67%.  12 cells segmented
# took 19.68s
#
# error in 2990b07d-701b-430b-b00d-abe4e8beb60c
# 84 out of 559, 14.85%.  -1 cells segmented
# took 2.87s
#
# 85 out of 559, 15.03%.  16 cells segmented
# took 21.92s
#
# 86 out of 559, 15.21%.  18 cells segmented
# took 22.45s
#
# 87 out of 559, 15.38%.  8 cells segmented
# took 19.84s
#
# 88 out of 559, 15.56%.  17 cells segmented
# took 22.36s
#
# 89 out of 559, 15.74%.  63 cells segmented
# took 59.01s
#
# 90 out of 559, 15.92%.  15 cells segmented
# took 21.40s
#
# 91 out of 559, 16.10%.  10 cells segmented
# took 19.72s
#
# 92 out of 559, 16.28%.  14 cells segmented
# took 20.64s
#
# error in 2dd34a23-84bb-4849-a285-cb60fb40ac47
# 93 out of 559, 16.46%.  -1 cells segmented
# took 3.11s
#
# 94 out of 559, 16.64%.  13 cells segmented
# took 21.86s
#
# 95 out of 559, 16.82%.  12 cells segmented
# took 20.52s
#
# 96 out of 559, 16.99%.  61 cells segmented
# took 56.12s
#
# error in 3011d306-da16-43c5-9c7a-46953c4e5a32
# 97 out of 559, 17.17%.  -1 cells segmented
# took 6.85s
#
# 98 out of 559, 17.35%.  14 cells segmented
# took 19.28s
#
# 99 out of 559, 17.53%.  15 cells segmented
# took 22.49s
#
# 100 out of 559, 17.71%.  10 cells segmented
# took 20.53s
#
# 101 out of 559, 17.89%.  36 cells segmented
# took 25.55s
#
# 102 out of 559, 18.07%.  55 cells segmented
# took 24.85s
#
# 103 out of 559, 18.25%.  11 cells segmented
# took 21.33s
#
# 104 out of 559, 18.43%.  15 cells segmented
# took 19.16s
#
# 105 out of 559, 18.60%.  15 cells segmented
# took 20.67s
#
# 106 out of 559, 18.78%.  12 cells segmented
# took 21.70s
#
# error in 33658e9c-d07d-46c5-b5ec-046338509a3e
# 107 out of 559, 18.96%.  -1 cells segmented
# took 2.96s
#
# 108 out of 559, 19.14%.  10 cells segmented
# took 42.16s
#
# error in 33932b91-1844-42f7-9363-90f72dae37a4
# 109 out of 559, 19.32%.  -1 cells segmented
# took 3.75s
#
# 110 out of 559, 19.50%.  18 cells segmented
# took 22.42s
#
# 111 out of 559, 19.68%.  16 cells segmented
# took 22.07s
#
# 112 out of 559, 19.86%.  13 cells segmented
# took 20.68s
#
# 113 out of 559, 20.04%.  15 cells segmented
# took 22.01s
#
# 114 out of 559, 20.21%.  12 cells segmented
# took 21.77s
#
# 115 out of 559, 20.39%.  19 cells segmented
# took 22.45s
#
# error in 35b9fbab-b3cc-4b7f-bc4f-3798edae38ae
# 116 out of 559, 20.57%.  -1 cells segmented
# took 3.30s
#
# 117 out of 559, 20.75%.  14 cells segmented
# took 21.02s
#
# 118 out of 559, 20.93%.  41 cells segmented
# took 23.81s
#
# 119 out of 559, 21.11%.  26 cells segmented
# took 24.68s
#
# 120 out of 559, 21.29%.  11 cells segmented
# took 22.57s
#
# 121 out of 559, 21.47%.  11 cells segmented
# took 22.57s
#
# 122 out of 559, 21.65%.  21 cells segmented
# took 21.99s
#
# 123 out of 559, 21.82%.  11 cells segmented
# took 18.91s
#
# 124 out of 559, 22.00%.  33 cells segmented
# took 25.44s
#
# error in 3bacbe9a-7c06-42c3-aabc-21a59c59c4d2
# 125 out of 559, 22.18%.  -1 cells segmented
# took 3.79s
#
# 126 out of 559, 22.36%.  21 cells segmented
# took 21.07s
#
# 127 out of 559, 22.54%.  10 cells segmented
# took 19.69s
#
# 128 out of 559, 22.72%.  26 cells segmented
# took 24.45s
#
# error in 3ec0dd97-bc18-4afa-b2dc-62f5df9ac9cd
# 129 out of 559, 22.90%.  -1 cells segmented
# took 3.34s
#
# error in 3efa7d8e-161b-48f1-8f18-013de3bc6cc0
# 130 out of 559, 23.08%.  -1 cells segmented
# took 3.48s
#
# error in 3ffb5912-8e8c-4857-ad8f-9871c31adf65
# 131 out of 559, 23.26%.  -1 cells segmented
# took 3.27s
# 132 out of 559, 23.43%.  19 cells segmented
# took 24.89s
#
# 133 out of 559, 23.61%.  19 cells segmented
# took 23.31s
#
# 134 out of 559, 23.79%.  15 cells segmented
# took 23.04s
#
# 135 out of 559, 23.97%.  38 cells segmented
# took 25.25s
#
# 136 out of 559, 24.15%.  87 cells segmented
# took 29.60s
#
# 137 out of 559, 24.33%.  20 cells segmented
# took 23.55s
#
# 138 out of 559, 24.51%.  9 cells segmented
# took 20.78s
#
# 139 out of 559, 24.69%.  9 cells segmented
# took 21.19s
#
# 140 out of 559, 24.87%.  20 cells segmented
# took 24.45s
#
# 141 out of 559, 25.04%.  29 cells segmented
# took 25.38s
#
# 142 out of 559, 25.22%.  17 cells segmented
# took 23.60s
#
# 143 out of 559, 25.40%.  20 cells segmented
# took 24.63s
#
# 144 out of 559, 25.58%.  15 cells segmented
# took 22.62s
#
# 145 out of 559, 25.76%.  19 cells segmented
# took 24.83s
#
# 146 out of 559, 25.94%.  17 cells segmented
# took 24.46s
#
# 147 out of 559, 26.12%.  18 cells segmented
# took 21.70s
#
# 148 out of 559, 26.30%.  7 cells segmented
# took 19.71s
#
# 149 out of 559, 26.48%.  13 cells segmented
# took 20.80s
#
# 150 out of 559, 26.65%.  22 cells segmented
# took 23.42s
#
# error in 4a11d63d-4b10-4a67-acb6-c8e0621c6180
# 151 out of 559, 26.83%.  -1 cells segmented
# took 3.05s
#
# 152 out of 559, 27.01%.  21 cells segmented
# took 22.96s
#
# error in 4aee3c20-4f67-41c1-9f41-6a18ff3f09cc
# 153 out of 559, 27.19%.  -1 cells segmented
# took 3.32s
#
# 154 out of 559, 27.37%.  32 cells segmented
# took 25.93s
#
# 155 out of 559, 27.55%.  23 cells segmented
# took 24.03s
#
# 156 out of 559, 27.73%.  17 cells segmented
# took 24.12s
#
# 157 out of 559, 27.91%.  20 cells segmented
# took 23.10s
#
# 158 out of 559, 28.09%.  11 cells segmented
# took 19.93s
#
# 159 out of 559, 28.26%.  29 cells segmented
# took 26.12s
#
# 160 out of 559, 28.44%.  16 cells segmented
# took 23.18s
#
# 161 out of 559, 28.62%.  13 cells segmented
# took 20.08s
#
# 162 out of 559, 28.80%.  20 cells segmented
# took 21.85s
#
# 163 out of 559, 28.98%.  12 cells segmented
# took 21.02s
#
# 164 out of 559, 29.16%.  14 cells segmented
# took 21.73s
#
# 165 out of 559, 29.34%.  27 cells segmented
# took 20.84s
#
# 166 out of 559, 29.52%.  15 cells segmented
# took 24.16s
#
# 167 out of 559, 29.70%.  20 cells segmented
# took 24.06s
#
# 168 out of 559, 29.87%.  19 cells segmented
# took 22.52s
#
# 169 out of 559, 30.05%.  14 cells segmented
# took 23.44s
#
# 170 out of 559, 30.23%.  24 cells segmented
# took 22.99s
#
# error in 50dec4d4-a343-464a-a4ff-9f233301184b
# 171 out of 559, 30.41%.  -1 cells segmented
# took 3.37s
#
# 172 out of 559, 30.59%.  22 cells segmented
# took 24.41s
#
# 173 out of 559, 30.77%.  17 cells segmented
# took 20.88s
#
# error in 52173c83-0c3f-42ce-82de-a965f3a0d830
# 174 out of 559, 30.95%.  -1 cells segmented
# took 3.30s
#
# 175 out of 559, 31.13%.  19 cells segmented
# took 20.78s
#
# 176 out of 559, 31.31%.  10 cells segmented
# took 21.51s
#
# 177 out of 559, 31.48%.  11 cells segmented
# took 19.73s
#
# 178 out of 559, 31.66%.  16 cells segmented
# took 23.11s
#
# 179 out of 559, 31.84%.  18 cells segmented
# took 21.84s
#
# error in 54016809-dc74-461c-b98f-62b4c151c769
# 180 out of 559, 32.02%.  -1 cells segmented
# took 3.23s
#
# 181 out of 559, 32.20%.  19 cells segmented
# took 22.57s
#
# 182 out of 559, 32.38%.  11 cells segmented
# took 21.95s
#
# error in 567e675f-f1b3-4ea6-80ec-00c85013ce89
# 183 out of 559, 32.56%.  -1 cells segmented
# took 2.82s
#
# 184 out of 559, 32.74%.  16 cells segmented
# took 23.35s
#
# 185 out of 559, 32.92%.  6 cells segmented
# took 18.96s
#
# 186 out of 559, 33.09%.  14 cells segmented
# took 19.76s
#
# 187 out of 559, 33.27%.  37 cells segmented
# took 58.02s
#
# 188 out of 559, 33.45%.  16 cells segmented
# took 21.25s
#
# 189 out of 559, 33.63%.  18 cells segmented
# took 22.34s
#
# 190 out of 559, 33.81%.  20 cells segmented
# took 22.86s
#
# 191 out of 559, 33.99%.  14 cells segmented
# took 22.14s
#
# 192 out of 559, 34.17%.  31 cells segmented
# took 48.77s
#
# 193 out of 559, 34.35%.  29 cells segmented
# took 21.32s
#
# error in 5af9bb81-719a-4374-9a12-5e5665329df6
# 194 out of 559, 34.53%.  -1 cells segmented
# took 3.65s
#
# 195 out of 559, 34.70%.  16 cells segmented
# took 23.71s
#
# 196 out of 559, 34.88%.  17 cells segmented
# took 23.56s
#
# 197 out of 559, 35.06%.  16 cells segmented
# took 23.78s
#
# 198 out of 559, 35.24%.  20 cells segmented
# took 24.19s
#
# 199 out of 559, 35.42%.  27 cells segmented
# took 25.15s
#
# 200 out of 559, 35.60%.  18 cells segmented
# took 24.07s
#
# 201 out of 559, 35.78%.  62 cells segmented
# took 58.45s
#
# 202 out of 559, 35.96%.  29 cells segmented
# took 23.77s
#
# 203 out of 559, 36.14%.  13 cells segmented
# took 22.78s
#
# 204 out of 559, 36.31%.  7 cells segmented
# took 21.19s
#
# 205 out of 559, 36.49%.  25 cells segmented
# took 23.91s
#
# 206 out of 559, 36.67%.  12 cells segmented
# took 23.72s
#
# 207 out of 559, 36.85%.  11 cells segmented
# took 23.57s
#
# 208 out of 559, 37.03%.  35 cells segmented
# took 22.41s
#
# 209 out of 559, 37.21%.  14 cells segmented
# took 24.56s
#
# 210 out of 559, 37.39%.  40 cells segmented
# took 56.73s
#
# 211 out of 559, 37.57%.  25 cells segmented
# took 22.81s
#
# 212 out of 559, 37.75%.  9 cells segmented
# took 18.85s
#
# 213 out of 559, 37.92%.  15 cells segmented
# took 20.53s
#
# 214 out of 559, 38.10%.  28 cells segmented
# took 23.53s
#
# 215 out of 559, 38.28%.  9 cells segmented
# took 19.77s
#
# 216 out of 559, 38.46%.  13 cells segmented
# took 23.40s
#
# error in 662d092f-ae4a-411a-9c4e-b1b9ce3f5196
# 217 out of 559, 38.64%.  -1 cells segmented
# took 2.87s
#
# 218 out of 559, 38.82%.  18 cells segmented
# took 23.02s
#
# 219 out of 559, 39.00%.  12 cells segmented
# took 19.94s
#
# 220 out of 559, 39.18%.  11 cells segmented
# took 20.91s
#
# 221 out of 559, 39.36%.  11 cells segmented
# took 22.16s
#
# error in 66db0c73-246b-4a21-bb77-ada5acf2692d
# 222 out of 559, 39.53%.  -1 cells segmented
# took 2.83s
#
# 223 out of 559, 39.71%.  11 cells segmented
# took 21.15s
#
# 224 out of 559, 39.89%.  22 cells segmented
# took 46.61s
#
# 225 out of 559, 40.07%.  13 cells segmented
# took 21.85s
#
# error in 67ff4e10-fc8e-46bc-b323-9c550e630c8d
# 226 out of 559, 40.25%.  -1 cells segmented
# took 3.15s
#
# 227 out of 559, 40.43%.  16 cells segmented
# took 21.19s
#
# 228 out of 559, 40.61%.  92 cells segmented
# took 67.99s
#
# 229 out of 559, 40.79%.  11 cells segmented
# took 20.49s
#
# 230 out of 559, 40.97%.  25 cells segmented
# took 23.08s
#
# 231 out of 559, 41.14%.  17 cells segmented
# took 23.69s
#
# 232 out of 559, 41.32%.  17 cells segmented
# took 23.27s
#
# 233 out of 559, 41.50%.  17 cells segmented
# took 21.46s
#
# 234 out of 559, 41.68%.  19 cells segmented
# took 23.53s
#
# error in 6fb09267-c6ae-4472-896e-b922870ba7e0
# 235 out of 559, 41.86%.  -1 cells segmented
# took 3.06s
#
# 236 out of 559, 42.04%.  11 cells segmented
# took 21.98s
#
# 237 out of 559, 42.22%.  18 cells segmented
# took 23.43s
#
# 238 out of 559, 42.40%.  12 cells segmented
# took 20.51s
#
# 239 out of 559, 42.58%.  15 cells segmented
# took 23.26s
#
# 240 out of 559, 42.75%.  21 cells segmented
# took 23.69s
#
# 241 out of 559, 42.93%.  38 cells segmented
# took 22.27s
#
# 242 out of 559, 43.11%.  17 cells segmented
# took 23.88s
#
# 243 out of 559, 43.29%.  11 cells segmented
# took 21.28s
#
# 244 out of 559, 43.47%.  85 cells segmented
# took 29.02s
#
# 245 out of 559, 43.65%.  18 cells segmented
# took 23.96s
#
# 246 out of 559, 43.83%.  12 cells segmented
# took 21.41s
#
# error in 75bf5e12-29d3-4a69-bf49-c7fb7fff2996
# 247 out of 559, 44.01%.  -1 cells segmented
# took 4.81s
#
# 248 out of 559, 44.19%.  12 cells segmented
# took 22.73s
#
# 249 out of 559, 44.36%.  17 cells segmented
# took 23.18s
#
# error in 78c2dcc6-f7ed-4c89-aa2b-53dcf7b9e601
# 250 out of 559, 44.54%.  -1 cells segmented
# took 3.23s
#
# 251 out of 559, 44.72%.  29 cells segmented
# took 26.63s
#
# 252 out of 559, 44.90%.  10 cells segmented
# took 21.20s
#
# 253 out of 559, 45.08%.  20 cells segmented
# took 23.40s
#
# 254 out of 559, 45.26%.  17 cells segmented
# took 23.88s
#
# error in 7ca5f161-cbe7-4c9c-90f6-0c51a7c260f4
# 255 out of 559, 45.44%.  -1 cells segmented
# took 5.13s
#
# error in 7cde5902-bab9-4245-b4b0-7cf04e1875be
# 256 out of 559, 45.62%.  -1 cells segmented
# took 3.70s
#
# 257 out of 559, 45.80%.  31 cells segmented
# took 23.97s
#
# 258 out of 559, 45.97%.  17 cells segmented
# took 25.28s
#
# 259 out of 559, 46.15%.  21 cells segmented
# took 22.04s
#
# 260 out of 559, 46.33%.  7 cells segmented
# took 24.42s
#
# 261 out of 559, 46.51%.  13 cells segmented
# took 22.45s
#
# 262 out of 559, 46.69%.  32 cells segmented
# took 25.56s
#
# 263 out of 559, 46.87%.  14 cells segmented
# took 21.94s
#
# 264 out of 559, 47.05%.  20 cells segmented
# took 26.75s
# 265 out of 559, 47.23%.  30 cells segmented
# took 25.75s
#
# 266 out of 559, 47.41%.  17 cells segmented
# took 21.97s
#
# 267 out of 559, 47.58%.  14 cells segmented
# took 21.91s
#
# 268 out of 559, 47.76%.  102 cells segmented
# took 32.47s
#
# 269 out of 559, 47.94%.  20 cells segmented
# took 21.36s
#
# 270 out of 559, 48.12%.  16 cells segmented
# took 21.93s
#
# 271 out of 559, 48.30%.  14 cells segmented
# took 25.21s
#
# 272 out of 559, 48.48%.  30 cells segmented
# took 50.87s
#
# 273 out of 559, 48.66%.  42 cells segmented
# took 27.89s
#
# 274 out of 559, 48.84%.  66 cells segmented
# took 26.86s
#
# 275 out of 559, 49.02%.  21 cells segmented
# took 20.83s
#
# 276 out of 559, 49.19%.  21 cells segmented
# took 24.52s
#
# error in 828927e2-84f2-42bf-b62b-be90b7eacd6f
# 277 out of 559, 49.37%.  -1 cells segmented
# took 3.44s
#
# 278 out of 559, 49.55%.  21 cells segmented
# took 22.24s
#
# 279 out of 559, 49.73%.  35 cells segmented
# took 23.80s
#
# 280 out of 559, 49.91%.  24 cells segmented
# took 24.36s
#
# 281 out of 559, 50.09%.  15 cells segmented
# took 25.84s
#
# 282 out of 559, 50.27%.  8 cells segmented
# took 20.26s
#
# 283 out of 559, 50.45%.  15 cells segmented
# took 21.17s
#
# 284 out of 559, 50.63%.  44 cells segmented
# took 52.30s
#
# 285 out of 559, 50.81%.  7 cells segmented
# took 19.79s
#
# 286 out of 559, 50.98%.  20 cells segmented
# took 25.60s
#
# 287 out of 559, 51.16%.  17 cells segmented
# took 23.99s
#
# 288 out of 559, 51.34%.  12 cells segmented
# took 21.72s
#
# 289 out of 559, 51.52%.  13 cells segmented
# took 23.42s
#
# 290 out of 559, 51.70%.  7 cells segmented
# took 21.01s
#
# error in 88fcdbef-cac1-4990-adda-6c0935610aa2
# 291 out of 559, 51.88%.  -1 cells segmented
# took 2.82s
#
# error in 8959efcc-75e9-4cf3-b35d-d9fd7eab88cc
# 292 out of 559, 52.06%.  -1 cells segmented
# took 2.66s
#
# error in 89754d37-1d55-4e5a-9e33-bde4148c0c4b
# 293 out of 559, 52.24%.  -1 cells segmented
# took 2.68s
#
# 294 out of 559, 52.42%.  18 cells segmented
# took 28.76s
#
# 295 out of 559, 52.59%.  51 cells segmented
# took 24.69s
#
# 296 out of 559, 52.77%.  19 cells segmented
# took 24.01s
#
# 297 out of 559, 52.95%.  13 cells segmented
# took 20.65s
#
# 298 out of 559, 53.13%.  16 cells segmented
# took 22.15s
#
# 299 out of 559, 53.31%.  32 cells segmented
# took 22.31s
#
# 300 out of 559, 53.49%.  17 cells segmented
# took 23.43s
#
# 301 out of 559, 53.67%.  14 cells segmented
# took 22.68s
#
# 302 out of 559, 53.85%.  18 cells segmented
# took 22.79s
#
# 303 out of 559, 54.03%.  15 cells segmented
# took 21.98s
#
# 304 out of 559, 54.20%.  9 cells segmented
# took 18.83s
#
# 305 out of 559, 54.38%.  22 cells segmented
# took 24.24s
#
# 306 out of 559, 54.56%.  18 cells segmented
# took 22.09s
#
# 307 out of 559, 54.74%.  11 cells segmented
# took 21.40s
#
# 308 out of 559, 54.92%.  18 cells segmented
# took 19.66s
#
# error in 904a8ff0-87b1-4354-bb17-b09e928006b4
# 309 out of 559, 55.10%.  -1 cells segmented
# took 3.21s
#
# 310 out of 559, 55.28%.  16 cells segmented
# took 21.05s
#
# 311 out of 559, 55.46%.  35 cells segmented
# took 25.80s
#
# 312 out of 559, 55.64%.  15 cells segmented
# took 22.23s
#
# 313 out of 559, 55.81%.  13 cells segmented
# took 23.03s
#
# 314 out of 559, 55.99%.  17 cells segmented
# took 21.55s
#
# 315 out of 559, 56.17%.  17 cells segmented
# took 44.53s
#
# 316 out of 559, 56.35%.  12 cells segmented
# took 21.01s
#
# 317 out of 559, 56.53%.  14 cells segmented
# took 23.74s
#
# 318 out of 559, 56.71%.  14 cells segmented
# took 19.58s
#
# 319 out of 559, 56.89%.  26 cells segmented
# took 22.44s
#
# 320 out of 559, 57.07%.  23 cells segmented
# took 24.27s
#
# 321 out of 559, 57.25%.  12 cells segmented
# took 22.64s
#
# 322 out of 559, 57.42%.  16 cells segmented
# took 23.57s
#
# 323 out of 559, 57.60%.  19 cells segmented
# took 24.21s
#
# error in 995a8045-d38a-491e-aa26-85c02ecaf81e
# 324 out of 559, 57.78%.  -1 cells segmented
# took 3.00s
#
# 325 out of 559, 57.96%.  14 cells segmented
# took 21.91s
#
# 326 out of 559, 58.14%.  27 cells segmented
# took 48.42s
#
# 327 out of 559, 58.32%.  27 cells segmented
# took 22.91s
#
# 328 out of 559, 58.50%.  13 cells segmented
# took 20.01s
#
# error in 9a10e2c4-e7ed-41c3-b710-8ca0066a984d
# 329 out of 559, 58.68%.  -1 cells segmented
# took 3.14s
#
# 330 out of 559, 58.86%.  15 cells segmented
# took 24.12s
#
# 331 out of 559, 59.03%.  8 cells segmented
# took 22.20s
#
# error in 9b1d4b27-6946-4b86-a818-8e91029c3dfa
# 332 out of 559, 59.21%.  -1 cells segmented
# took 5.47s
#
# 333 out of 559, 59.39%.  15 cells segmented
# took 21.00s
#
# error in 9bbf402d-876e-4b4c-b308-0e48ddd1d199
# 334 out of 559, 59.57%.  -1 cells segmented
# took 3.00s
#
# 335 out of 559, 59.75%.  19 cells segmented
# took 22.58s
#
# 336 out of 559, 59.93%.  39 cells segmented
# took 23.73s
#
# 337 out of 559, 60.11%.  12 cells segmented
# took 22.83s
#
# 338 out of 559, 60.29%.  31 cells segmented
# took 26.98s
#
# 339 out of 559, 60.47%.  18 cells segmented
# took 22.61s
#
# 340 out of 559, 60.64%.  19 cells segmented
# took 21.85s
#
# 341 out of 559, 60.82%.  17 cells segmented
# took 23.74s
#
# 342 out of 559, 61.00%.  14 cells segmented
# took 21.55s
#
# 343 out of 559, 61.18%.  11 cells segmented
# took 28.75s
#
# 344 out of 559, 61.36%.  7 cells segmented
# took 19.56s
#
# 345 out of 559, 61.54%.  41 cells segmented
# took 22.71s
#
# 346 out of 559, 61.72%.  15 cells segmented
# took 20.76s
#
# error in a4508e8b-f8f7-49b4-9a29-535468b27dff
# 347 out of 559, 61.90%.  -1 cells segmented
# took 3.13s
#
# 348 out of 559, 62.08%.  15 cells segmented
# took 29.27s
#
# 349 out of 559, 62.25%.  12 cells segmented
# took 21.93s
#
# 350 out of 559, 62.43%.  7 cells segmented
# took 19.98s
#
# 351 out of 559, 62.61%.  19 cells segmented
# took 24.28s
#
# 352 out of 559, 62.79%.  7 cells segmented
# took 19.61s
#
# 353 out of 559, 62.97%.  12 cells segmented
# took 22.00s
#
# 354 out of 559, 63.15%.  17 cells segmented
# took 23.92s
#
# 355 out of 559, 63.33%.  17 cells segmented
# took 23.01s
#
# 356 out of 559, 63.51%.  13 cells segmented
# took 21.59s
#
# 357 out of 559, 63.69%.  13 cells segmented
# took 20.68s
#
# error in a951e8c5-8e1a-413e-b1be-bbd7d445a986
# 358 out of 559, 63.86%.  -1 cells segmented
# took 2.90s
#
# 359 out of 559, 64.04%.  22 cells segmented
# took 23.38s
#
# 360 out of 559, 64.22%.  28 cells segmented
# took 20.19s
#
# 361 out of 559, 64.40%.  22 cells segmented
# took 22.46s
#
# 362 out of 559, 64.58%.  16 cells segmented
# took 22.89s
#
# error in ae5710a8-9e14-4b9d-8535-2a2e1a05df9d
# 363 out of 559, 64.76%.  -1 cells segmented
# took 3.05s
#
# 364 out of 559, 64.94%.  16 cells segmented
# took 24.43s
#
# 365 out of 559, 65.12%.  26 cells segmented
# took 24.33s
#
# 366 out of 559, 65.30%.  18 cells segmented
# took 22.32s
#
# 367 out of 559, 65.47%.  17 cells segmented
# took 24.59s
#
# 368 out of 559, 65.65%.  14 cells segmented
# took 21.77s
#
# 369 out of 559, 65.83%.  14 cells segmented
# took 22.54s
#
# 370 out of 559, 66.01%.  13 cells segmented
# took 22.53s
#
# 371 out of 559, 66.19%.  19 cells segmented
# took 22.86s
#
# 372 out of 559, 66.37%.  28 cells segmented
# took 23.45s
#
# 373 out of 559, 66.55%.  21 cells segmented
# took 21.16s
#
# 374 out of 559, 66.73%.  12 cells segmented
# took 22.47s
#
# 375 out of 559, 66.91%.  19 cells segmented
# took 21.92s
#
# 376 out of 559, 67.08%.  12 cells segmented
# took 22.09s
#
# 377 out of 559, 67.26%.  17 cells segmented
# took 24.11s
#
# 378 out of 559, 67.44%.  39 cells segmented
# took 24.43s
#
# 379 out of 559, 67.62%.  18 cells segmented
# took 21.27s
#
# error in b36e3727-6b72-4f1d-bc92-5110e2649f05
# 380 out of 559, 67.80%.  -1 cells segmented
# took 3.15s
#
# 381 out of 559, 67.98%.  9 cells segmented
# took 20.75s
#
# 382 out of 559, 68.16%.  44 cells segmented
# took 24.62s
#
# 383 out of 559, 68.34%.  9 cells segmented
# took 18.39s
#
# 384 out of 559, 68.52%.  20 cells segmented
# took 23.26s
#
# 385 out of 559, 68.69%.  10 cells segmented
# took 25.56s
#
# 386 out of 559, 68.87%.  16 cells segmented
# took 23.48s
#
# 387 out of 559, 69.05%.  24 cells segmented
# took 25.41s
#
# 388 out of 559, 69.23%.  18 cells segmented
# took 20.62s
#
# error in b7bbe19b-34bb-4297-a546-425fa9cbce0e
# 389 out of 559, 69.41%.  -1 cells segmented
# took 3.28s
#
# 390 out of 559, 69.59%.  16 cells segmented
# took 29.44s
#
# 391 out of 559, 69.77%.  16 cells segmented
# took 23.12s
#
# 392 out of 559, 69.95%.  17 cells segmented
# took 22.54s
#
# 393 out of 559, 70.13%.  15 cells segmented
# took 22.28s
#
# 394 out of 559, 70.30%.  18 cells segmented
# took 22.92s
#
# 395 out of 559, 70.48%.  30 cells segmented
# took 21.23s
#
# 396 out of 559, 70.66%.  14 cells segmented
# took 20.55s
#
# 397 out of 559, 70.84%.  28 cells segmented
# took 22.73s
# 398 out of 559, 71.02%.  17 cells segmented
# took 24.80s
#
# 399 out of 559, 71.20%.  12 cells segmented
# took 20.71s
#
# 400 out of 559, 71.38%.  35 cells segmented
# took 24.30s
#
# 401 out of 559, 71.56%.  17 cells segmented
# took 24.75s
#
# 402 out of 559, 71.74%.  24 cells segmented
# took 22.04s
#
# 403 out of 559, 71.91%.  16 cells segmented
# took 22.35s
#
# 404 out of 559, 72.09%.  22 cells segmented
# took 23.59s
#
# 405 out of 559, 72.27%.  34 cells segmented
# took 26.02s
#
# 406 out of 559, 72.45%.  11 cells segmented
# took 21.36s
#
# 407 out of 559, 72.63%.  15 cells segmented
# took 24.84s
#
# error in bd661fb6-95bf-46fa-a884-fcc56c24e993
# 408 out of 559, 72.81%.  -1 cells segmented
# took 3.09s
#
# 409 out of 559, 72.99%.  23 cells segmented
# took 25.57s
#
# 410 out of 559, 73.17%.  17 cells segmented
# took 23.42s
#
# 411 out of 559, 73.35%.  24 cells segmented
# took 24.18s
#
# 412 out of 559, 73.52%.  22 cells segmented
# took 25.02s
#
# 413 out of 559, 73.70%.  38 cells segmented
# took 31.38s
#
# 414 out of 559, 73.88%.  13 cells segmented
# took 23.53s
#
# error in c11ebeea-fbf8-4e6c-9817-3615b5e7a97e
# 415 out of 559, 74.06%.  -1 cells segmented
# took 3.12s
#
# 416 out of 559, 74.24%.  11 cells segmented
# took 21.72s
#
# 417 out of 559, 74.42%.  9 cells segmented
# took 20.88s
#
# 418 out of 559, 74.60%.  16 cells segmented
# took 27.66s
#
# 419 out of 559, 74.78%.  18 cells segmented
# took 27.56s
#
# 420 out of 559, 74.96%.  32 cells segmented
# took 48.34s
#
# 421 out of 559, 75.13%.  17 cells segmented
# took 22.96s
#
# 422 out of 559, 75.31%.  13 cells segmented
# took 22.05s
#
# 423 out of 559, 75.49%.  43 cells segmented
# took 26.55s
#
# 424 out of 559, 75.67%.  13 cells segmented
# took 22.33s
#
# 425 out of 559, 75.85%.  12 cells segmented
# took 22.43s
#
# 426 out of 559, 76.03%.  16 cells segmented
# took 23.76s
#
# 427 out of 559, 76.21%.  37 cells segmented
# took 22.95s
#
# 428 out of 559, 76.39%.  62 cells segmented
# took 63.90s
#
# 429 out of 559, 76.57%.  17 cells segmented
# took 21.82s
#
# 430 out of 559, 76.74%.  25 cells segmented
# took 22.89s
#
# 431 out of 559, 76.92%.  16 cells segmented
# took 24.42s
#
# 432 out of 559, 77.10%.  13 cells segmented
# took 21.04s
#
# 433 out of 559, 77.28%.  12 cells segmented
# took 21.87s
#
# error in c89b2a8b-c2fd-4bc1-abcc-6528706f6f8e
# 434 out of 559, 77.46%.  -1 cells segmented
# took 3.17s
#
# 435 out of 559, 77.64%.  13 cells segmented
# took 20.26s
#
# 436 out of 559, 77.82%.  13 cells segmented
# took 22.66s
#
# error in ca01fc73-a926-4911-8d34-571a519a9fbb
# 437 out of 559, 78.00%.  -1 cells segmented
# took 2.84s
#
# 438 out of 559, 78.18%.  12 cells segmented
# took 22.54s
#
# 439 out of 559, 78.35%.  31 cells segmented
# took 56.43s
#
# 440 out of 559, 78.53%.  18 cells segmented
# took 21.78s
#
# 441 out of 559, 78.71%.  20 cells segmented
# took 23.19s
#
# 442 out of 559, 78.89%.  48 cells segmented
# took 24.52s
#
# error in cc6f54e0-d9dc-4845-8142-8a92b0e079a8
# 443 out of 559, 79.07%.  -1 cells segmented
# took 4.32s
#
# 444 out of 559, 79.25%.  22 cells segmented
# took 23.30s
#
# 445 out of 559, 79.43%.  41 cells segmented
# took 47.08s
#
# 446 out of 559, 79.61%.  19 cells segmented
# took 21.77s
#
# 447 out of 559, 79.79%.  14 cells segmented
# took 22.25s
#
# error in cee36bfb-c562-4ffc-9cd5-0e0cccf22786
# 448 out of 559, 79.96%.  -1 cells segmented
# took 3.21s
#
# 449 out of 559, 80.14%.  21 cells segmented
# took 20.77s
#
# 450 out of 559, 80.32%.  16 cells segmented
# took 24.22s
#
# 451 out of 559, 80.50%.  13 cells segmented
# took 21.63s
#
# 452 out of 559, 80.68%.  13 cells segmented
# took 44.34s
#
# 453 out of 559, 80.86%.  9 cells segmented
# took 21.25s
#
# 454 out of 559, 81.04%.  17 cells segmented
# took 19.68s
#
# 455 out of 559, 81.22%.  16 cells segmented
# took 22.82s
#
# 456 out of 559, 81.40%.  14 cells segmented
# took 22.04s
#
# 457 out of 559, 81.57%.  20 cells segmented
# took 21.50s
#
# 458 out of 559, 81.75%.  28 cells segmented
# took 24.86s
#
# 459 out of 559, 81.93%.  46 cells segmented
# took 55.81s
#
# 460 out of 559, 82.11%.  8 cells segmented
# took 20.82s
#
# 461 out of 559, 82.29%.  12 cells segmented
# took 21.54s
#
# 462 out of 559, 82.47%.  16 cells segmented
# took 20.31s
#
# 463 out of 559, 82.65%.  22 cells segmented
# took 22.29s
#
# 464 out of 559, 82.83%.  20 cells segmented
# took 24.83s
#
# 465 out of 559, 83.01%.  24 cells segmented
# took 20.87s
#
# 466 out of 559, 83.18%.  11 cells segmented
# took 19.46s
#
# 467 out of 559, 83.36%.  14 cells segmented
# took 20.57s
#
# 468 out of 559, 83.54%.  22 cells segmented
# took 21.12s
#
# error in dcdfc60a-2ed9-49ce-99ec-6c51c4b655b2
# 469 out of 559, 83.72%.  -1 cells segmented
# took 3.22s
#
# 470 out of 559, 83.90%.  21 cells segmented
# took 23.44s
#
# 471 out of 559, 84.08%.  29 cells segmented
# took 24.51s
#
# 472 out of 559, 84.26%.  6 cells segmented
# took 20.65s
#
# 473 out of 559, 84.44%.  8 cells segmented
# took 23.31s
#
# 474 out of 559, 84.62%.  14 cells segmented
# took 20.58s
#
# 475 out of 559, 84.79%.  9 cells segmented
# took 21.45s
#
# 476 out of 559, 84.97%.  15 cells segmented
# took 24.55s
#
# 477 out of 559, 85.15%.  21 cells segmented
# took 24.56s
#
# 478 out of 559, 85.33%.  10 cells segmented
# took 22.34s
#
# 479 out of 559, 85.51%.  17 cells segmented
# took 24.39s
#
# 480 out of 559, 85.69%.  16 cells segmented
# took 21.75s
#
# 481 out of 559, 85.87%.  13 cells segmented
# took 26.70s
#
# 482 out of 559, 86.05%.  12 cells segmented
# took 22.37s
#
# 483 out of 559, 86.23%.  82 cells segmented
# took 64.57s
#
# error in e43e26e6-f2a9-487e-b975-deb068475f59
# 484 out of 559, 86.40%.  -1 cells segmented
# took 7.56s
#
# 485 out of 559, 86.58%.  17 cells segmented
# took 23.39s
#
# 486 out of 559, 86.76%.  12 cells segmented
# took 20.64s
#
# 487 out of 559, 86.94%.  14 cells segmented
# took 22.99s
#
# 488 out of 559, 87.12%.  32 cells segmented
# took 23.05s
#
# 489 out of 559, 87.30%.  25 cells segmented
# took 52.89s
#
# 490 out of 559, 87.48%.  38 cells segmented
# took 24.42s
#
# 491 out of 559, 87.66%.  35 cells segmented
# took 25.21s
#
# 492 out of 559, 87.84%.  11 cells segmented
# took 21.63s
#
# 493 out of 559, 88.01%.  11 cells segmented
# took 22.34s
#
# 494 out of 559, 88.19%.  23 cells segmented
# took 44.69s
#
# 495 out of 559, 88.37%.  87 cells segmented
# took 67.51s
#
# 496 out of 559, 88.55%.  20 cells segmented
# took 50.06s
#
# 497 out of 559, 88.73%.  14 cells segmented
# took 30.71s
#
# 498 out of 559, 88.91%.  11 cells segmented
# took 21.30s
#
# error in ea91119b-021e-4376-9ec4-0a08867c221c
# 499 out of 559, 89.09%.  -1 cells segmented
# took 3.03s
#
# 500 out of 559, 89.27%.  17 cells segmented
# took 29.62s
#
# 501 out of 559, 89.45%.  16 cells segmented
# took 26.50s
#
# 502 out of 559, 89.62%.  14 cells segmented
# took 29.08s
#
# 503 out of 559, 89.80%.  33 cells segmented
# took 28.16s
#
# 504 out of 559, 89.98%.  16 cells segmented
# took 24.57s
#
# 505 out of 559, 90.16%.  11 cells segmented
# took 25.02s
#
# 506 out of 559, 90.34%.  21 cells segmented
# took 25.38s
#
# 507 out of 559, 90.52%.  16 cells segmented
# took 23.06s
#
# 508 out of 559, 90.70%.  16 cells segmented
# took 23.42s
#
# 509 out of 559, 90.88%.  21 cells segmented
# took 21.38s
#
# 510 out of 559, 91.06%.  17 cells segmented
# took 25.28s
#
# 511 out of 559, 91.23%.  10 cells segmented
# took 24.63s
#
# 512 out of 559, 91.41%.  13 cells segmented
# took 24.00s
#
# 513 out of 559, 91.59%.  20 cells segmented
# took 28.97s
#
# error in effb9cf8-fa56-4916-8fd3-ce19f1c0747f
# 514 out of 559, 91.77%.  -1 cells segmented
# took 4.60s
#
# 515 out of 559, 91.95%.  7 cells segmented
# took 21.92s
#
# 516 out of 559, 92.13%.  14 cells segmented
# took 22.93s
#
# error in f2338d73-448d-47c1-ace9-7f16cb3c8c38
# 517 out of 559, 92.31%.  -1 cells segmented
# took 3.07s
#
# 518 out of 559, 92.49%.  20 cells segmented
# took 27.48s
#
# 519 out of 559, 92.67%.  17 cells segmented
# took 26.87s
#
# 520 out of 559, 92.84%.  12 cells segmented
# took 26.14s
#
# 521 out of 559, 93.02%.  40 cells segmented
# took 30.93s
#
# 522 out of 559, 93.20%.  28 cells segmented
# took 27.82s
#
# 523 out of 559, 93.38%.  20 cells segmented
# took 24.43s
#
# 524 out of 559, 93.56%.  13 cells segmented
# took 21.24s
#
# 525 out of 559, 93.74%.  14 cells segmented
# took 20.70s
#
# 526 out of 559, 93.92%.  33 cells segmented
# took 27.39s
#
# 527 out of 559, 94.10%.  8 cells segmented
# took 21.42s
#
# 528 out of 559, 94.28%.  18 cells segmented
# took 21.17s
#
# 529 out of 559, 94.45%.  14 cells segmented
# took 23.56s
#
# error in f755d19e-f779-43ec-9c26-da63707e033c
# 530 out of 559, 94.63%.  -1 cells segmented
# took 2.94s
#
# 531 out of 559, 94.81%.  13 cells segmented
# took 25.64s
#
# 532 out of 559, 94.99%.  8 cells segmented
# took 26.89s
# 533 out of 559, 95.17%.  39 cells segmented
# took 27.68s
#
# error in fa1c891d-7660-461d-8299-afd1aa2d6609
# 534 out of 559, 95.35%.  -1 cells segmented
# took 3.86s
#
# 535 out of 559, 95.53%.  42 cells segmented
# took 57.93s
#
# 536 out of 559, 95.71%.  7 cells segmented
# took 24.13s
#
# error in fb18d293-0c98-4ace-8c1b-fe9f17e9878e
# 537 out of 559, 95.89%.  -1 cells segmented
# took 6.39s
#
# 538 out of 559, 96.06%.  26 cells segmented
# took 26.10s
#
# error in fb614e7d-3c4d-432c-8452-2d708acf5eb6
# 539 out of 559, 96.24%.  -1 cells segmented
# took 3.15s
#
# error in fc2319d7-6118-4677-a560-e40f05140317
# 540 out of 559, 96.42%.  -1 cells segmented
# took 3.46s
#
# 541 out of 559, 96.60%.  14 cells segmented
# took 28.26s
#
# 542 out of 559, 96.78%.  23 cells segmented
# took 27.44s
#
# 543 out of 559, 96.96%.  28 cells segmented
# took 27.57s
#
# 544 out of 559, 97.14%.  15 cells segmented
# took 27.96s
#
# 545 out of 559, 97.32%.  13 cells segmented
# took 25.17s
#
# 546 out of 559, 97.50%.  57 cells segmented
# took 33.70s
#
# 547 out of 559, 97.67%.  28 cells segmented
# took 26.76s
#
# 548 out of 559, 97.85%.  28 cells segmented
# took 27.16s
#
# 549 out of 559, 98.03%.  40 cells segmented
# took 32.53s
#
# 550 out of 559, 98.21%.  26 cells segmented
# took 55.15s
#
# error in fdd126fa-8e87-4ffe-b2b7-3ee48156d887
# 551 out of 559, 98.39%.  -1 cells segmented
# took 4.04s
#
# error in fdf38d34-19f6-491f-b2e2-143a446736c0
# 552 out of 559, 98.57%.  -1 cells segmented
# took 4.32s
#
# 553 out of 559, 98.75%.  8 cells segmented
# took 26.11s
#
# 554 out of 559, 98.93%.  18 cells segmented
# took 37.04s
#
# error in fea47298-266a-4cf4-93bd-55d1bcc2fc7d
# 555 out of 559, 99.11%.  -1 cells segmented
# took 3.18s
#
# 556 out of 559, 99.28%.  21 cells segmented
# took 26.17s
#
# 557 out of 559, 99.46%.  14 cells segmented
# took 22.82s
#
# 558 out of 559, 99.64%.  27 cells segmented
# took 56.13s
#
# 559 out of 559, 99.82%.  26 cells segmented
# took 30.88s
# /home/heather-bep/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
# This doesn't work
array_masks = np.load("/media/beta/mitko-beps/heather/encoded_masks.npy",  allow_pickle=True)

# %%
masks_flat_list = [item for sublist in all_enc_masks for item in sublist]
d = {"enc_masks": masks_flat_list}
df_enc = pd.DataFrame(data=d)
df_enc.to_csv("/media/beta/mitko-beps/heather/enc_masks.csv", index=False)

# %%
print(len(df_enc))
df_enc[0:10]
# Out:
# 11179
#                                            enc_masks
# 0  eNq1Vtty4jAM/SUUe+lLp53Z7swOtVGAUBwn5EIgN275/7...
# 1  eNqdUm1PwkAM/kvt3RgYDEaDkZd7QUKiCyIDCRgx8P+/eW...
# 2  eNoLCIgJMjbOzTc09AdB48gAP7OgfENbMM/IDyzma+4JoS...
# 3  eNqNUsuOwjAM/CXHrliQKg5oWV5NfIDLapG2qAgkLvz/jd...
# 4  eNp9UV2PmzAQ/Eus7SRVE6k9tbkmtVm+aiA0EAjxBUiA//...
# 5  eNqFVG1zojAQ/ktZoMrpjHfcqEwZWPRSlJdiqSIFLsr//3...
# 6  eNqtVemSojAQfiUazExt7QNMTVY6qyMqRziDiIq+/79NE0...
# 7  eNqNVG1z2jAM/kuWE9re3u52rDtoEpnRQC4NKSzQpKWs/P...
# 8  eNqVUk1vwjAM/UtxQrrDBJdtB7I0mcSIWAejlI8pwLT/f5...
# 9  eNqFVVl3okoQ/ksU6HjPHeZlzJxMjBREhGZfGpBF1P//dq...

# %%
""""
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from efficientnet import inject_tfkeras_modules, init_tfkeras_custom_objects
from efficientnet import model

# Import EfficientNetB0
EfficientNetB0 = inject_tfkeras_modules(model.EfficientNetB0)

# Load architecture
def build_model(num_classes):
    input_shape = (224, 224, 4)
    inputs = Input(input_shape)
    base_model = EfficientNetB0(include_top=False, input_tensor = inputs, input_shape = input_shape, weights=None)

    # Rebuild top
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.2)(x)
    x = Dense(num_classes, activation='sigmoid')(x)
    
    # Load the weights 
    model = tf.keras.models.Model(inputs, x)
    model.load_weights("/media/beta/mitko-beps/heather/Pretrained_model/EfficientNetB0_weights.hdf5")
    
    # Compile the model 
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)
    model.compile(
            optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"]
            )

    
    return model
"""

# %%
#model = build_model(19)
# Out:
# /media/beta/mitko-beps/heather/anaconda3/lib/python3.8/site-packages/keras_applications/imagenet_utils.py:276: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 4 input channels.
#   warnings.warn(

# %%
print((all_enc_masks[0][0]))
# Out:
# ...

# %%
import os
import tensorflow as tf
import pandas as pd 
import numpy as np

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
#load the model 
reload_model = tf.keras.models.load_model('/media/beta/mitko-beps/heather/MODEL_FT_HEATHER')
#reload_model = model

# %%
#
# load dataframe 
test = pd.read_csv('/media/beta/mitko-beps/heather/test_with_masks.csv')

sum(test["n_cells"])
# Out:
# 9853

# %%
sample_submission = pd.read_csv("/media/beta/mitko-beps/data/sample_submission.csv")
sample_submission.head()
df.head()
# Out:
#    ImageWidth  ImageHeight                                    ID  \
# 0        2048         2048  0040581b-f1f2-4fbe-b043-b6bfea5404bb
# 1        2048         2048  004a270d-34a2-4d60-bbe4-365fca868193
# 2        2048         2048  00537262-883c-4b37-a3a1-a4931b6faea5
# 3        2048         2048  00c9a1c9-2f06-476f-8b0d-6d01032874a2
# 4        3072         3072  0173029a-161d-40ef-af28-2342915b22fb
#
#            PredictionString
# 0  0 1 eNoLCAgIMAEABJkBdQ==
# 1  0 1 eNoLCAgIMAEABJkBdQ==
# 2  0 1 eNoLCAgIMAEABJkBdQ==
# 3  0 1 eNoLCAgIMAEABJkBdQ==
# 4  0 1 eNoLCAgIsAQABJ4Beg==

# %%
imgs_flat_list = [item for sublist in test_images for item in sublist]
len(imgs_flat_list)
# Out:
# 9853

# %%
prediction_list = []
confidence_list = []
classes_list = []

for one_list_with_images in (test_images): 
    pred = []
    cls = []    
    confid = []
    for image in one_list_with_images: 
        img = np.expand_dims(image, axis = 0)
        prediction = reload_model.predict(img) 
        pred.append(prediction)
        classes = np.argmax(prediction)
        cls.append(classes)
    for x in pred:
        confs = []
        
        for m in x: 
            confi = (max(m))
            confs.append(confi)
        
        confid.append(confs)
    
    flat_list = [item for sublist in confid for item in sublist]
    prediction_list.append(pred)
    classes_list.append(cls)
    confidence_list.append(flat_list)

# %%
flat_list = [item for sublist in classes_list for item in sublist]
print(flat_list.count(0))
# Out:
# 5054

# %%
predString =[]
for i in range(len(classes_list)):
    string = []
    #print(len(confidence_list[i]))
    for x in range(len(classes_list[i])): 
        conf = confidence_list[i][x]
        cls = classes_list[i][x] 
        masks = all_enc_masks[i][x]
        string.append(str(cls) +  " " + str(conf) + " "+ str(masks)+ " ")
    
    
    x = "".join(string) # this is prediction string!!
    x = x[:-1]
    predString.append(x)

# %%
ids = []
heig = []
wid = []
for i, row in test_df.iterrows(): 
    ID = row.ID
    ids.append(ID)
    height = row.ImageHeight
    heig.append(height)
    width = row.ImageWidth 
    wid.append(width)

d = {'ID': ids, 'ImageWidth': wid, 'ImageHeight': heig, 'PredictionString': predString}
df = pd.DataFrame(data=d)

# %%
""""
ids = []
heig = []
wid = []
for i, row in test_df.iterrows(): 
    ID = row.ID
    ids.append(ID)

d = {'ID': ids, 'PredictionString': all_enc_masks}
df_mask = pd.DataFrame(data=d)
""""

# %%
df.head()
# Out:
#                                      ID  ImageWidth  ImageHeight  \
# 0  0040581b-f1f2-4fbe-b043-b6bfea5404bb        2048         2048
# 1  004a270d-34a2-4d60-bbe4-365fca868193        2048         2048
# 2  00537262-883c-4b37-a3a1-a4931b6faea5        2048         2048
# 3  00c9a1c9-2f06-476f-8b0d-6d01032874a2        2048         2048
# 4  0173029a-161d-40ef-af28-2342915b22fb        3072         3072
#
#                                     PredictionString
# 0  0 0.3772697 eNq1Vtty4jAM/SUUe+lLp53Z7swOtVGAUB...
# 1  16 0.45604905 eNoLCEhJMLDIyDc09Df0N/bNNwj0h7Ds...
# 2  14 0.5436441 eNp1kn9PwjAQhr9SrwPcMFE0GYjQaxAYj...
# 3  12 0.3162971 eNrtVG1TwjAM/ktNN9npd7kx1lQBW1RA3...
# 4  16 0.63141745 eNq1VNuSojAQ/aXQqAU8bhWKI028zYAB...

# %%
df.to_csv("/media/beta/mitko-beps/heather/FineTuneResults.csv", index=False)

# %%
df["PredictionString"][0]
# Out:
# '0 0.93544114 ... 11 0.74602497 ... 0 0.36608642 eNoLCIgJMjbOzTc09AdB48gAP7OgfENbMM/IDyzma+4JoSF8BITJG/til8cFDeAAwkaIovOJBaTqI6Qelzwh9+LnI/xPHXF6yVPbHHpBWPokNl3S2n5c7iHVncgpEgDNX+Fg 11 0.76279354  0 0.6552887 ... 0 0.96040475 ... 0 0.89254606 ... 0 0.8091918 ... 0 0.7315174 ... 3 0.32979003 ... 0 0.7074574 ... 0 0.2781805 ... 0 0.9605553 ... 0 0.7816507 ... 0 0.46845785 '

# %%
df.to_csv("/media/beta/mitko-beps/heather/PRETRAIN.csv", index=False)

# %%
df = pd.read_csv("/media/beta/mitko-beps/heather/PRETRAIN_Kaggle.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-dfa6d3d93c43> in <module>
# ----> 1 df = pd.read_csv("/media/beta/mitko-beps/heather/PRETRAIN_Kaggle.csv")
#
# /media/beta/mitko-beps/heather/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# /media/beta/mitko-beps/heather/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# /media/beta/mitko-beps/heather/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# /media/beta/mitko-beps/heather/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# /media/beta/mitko-beps/heather/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/beta/mitko-beps/heather/PRETRAIN_Kaggle.csv'

# %%
df["PredictionString"][0]
# Out:
# '16 0.2981982 ... 3 0.34255266 ... 0 0.24438334 eNoLCIgJMjbOzTc09AdB48gAP7OgfENbMM/IDyzma+4JoSF8BITJG/til8cFDeAAwkaIovOJBaTqI6Qelzwh9+LnI/xPHXF6yVPbHHpBWPokNl3S2n5c7iHVncgpEgDNX+Fg 16 0.3012758  0 0.50774336 ... 0 0.43429333 ... 0 0.58050585 ... 16 0.29920095 ... 0 0.68147594 ... 16 0.15615392 ... 18 0.2862023 ... 16 0.30355573 ... 16 0.22376104 ... 16 0.36240554 ... 16 0.20469418 '
